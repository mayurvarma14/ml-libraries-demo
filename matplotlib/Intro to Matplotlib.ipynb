# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %% [markdown]
# **Note: Add semicolon at end to remove the output array or add plt.show**

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# ### Different methods to plot graph

# %% [markdown]
# **Method 1**

# %%
fig=plt.figure() #creates a figure
ax=fig.add_subplot() #adds some axes
plt.show()

# %% [markdown]
# **Method 2**

# %%
fig=plt.figure() #creates a figure
ax=fig.add_subplot() #adds some axes
ax.plot(x,y) #add data
plt.show()

# %% [markdown]
# **Method 3 (recommended)**

# %%
fig, ax=plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("simple-plot.png")

# %%
x= np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %% [markdown]
# **Line plot**

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# **Scatter plot**

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %% [markdown]
# **Scatter plot with sin wave**

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %% [markdown]
# **Bar plot**

# %%
butter_prices={"Almond butter":10,
              "Peanut butter":8,
               "Cashew butter":12,
              }
fig, ax = plt.subplots()
ax.bar(butter_prices.keys(),butter_prices.values())
ax.set(title="Mayur's Nut Butter Store", ylabel="Price ($)");

# %%
# Horizontal plot

fig, ax = plt.subplots()
ax.barh(list(butter_prices.keys()),list(butter_prices.values()));

# %% [markdown]
# **Histogram plot**

# %%
x= np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# option 1

fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(butter_prices.keys(),butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# option 2

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(butter_prices.keys(),butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %%
car_sales = pd.read_csv('../pandas/car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','').astype(int)/100
# Out:
# <ipython-input-70-61959452274d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','').astype(int)/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot(x="Sale Date",y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[4.96181287e-03, 3.65323623e-01, 8.23056844e-01, 5.17672391e-01],
#        [1.27328792e-01, 7.46512541e-01, 8.07508801e-01, 2.61921026e-04],
#        [1.65971240e-01, 1.38280093e-01, 8.68584582e-01, 2.30040411e-01],
#        [4.73560426e-01, 4.72698696e-01, 4.11789482e-01, 5.07058302e-01],
#        [6.36083766e-01, 7.69655281e-01, 1.47300627e-01, 3.13138694e-01],
#        [8.99338170e-01, 9.70103276e-01, 3.20640287e-01, 3.37120899e-01],
#        [8.80461350e-01, 1.40254399e-01, 7.73142375e-01, 6.86268346e-01],
#        [6.08209323e-01, 8.27730701e-01, 4.75920781e-01, 9.33971436e-01],
#        [3.86743270e-01, 5.42560610e-01, 6.26707727e-01, 6.07279665e-01],
#        [8.31416396e-01, 3.34458376e-01, 8.50786262e-01, 2.28863136e-01]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
heart_disease =  pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
fig, ax=plt.subplots(figsize=(10,6));
scatter= ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age",ylabel="Cholesterol")

ax.legend(*scatter.legend_elements(),title="Target")

ax.axhline(over_50["chol"].mean(),linestyle='--')

# %%
fig,(ax0,ax1)=plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True);

ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax0.set(title="Heart Disease and Cholesterol Levels",ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle='--')

ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart Disease and Cholesterol Levels", xlabel="Age",ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle='--')

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')
fig,(ax0,ax1)=plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True);

ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")
ax0.set(title="Heart Disease and Cholesterol Levels",ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle='--')
ax0.set_xlim([50,80])

ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],cmap="winter")
ax1.set(title="Heart Disease and Cholesterol Levels", xlabel="Age",ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle='--')
# changing x axis here is not req as its sharing same x axis
ax1.set_ylim([60,200])

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");
fig.savefig('heat-disease-analysis.png')
